# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import pandasql as ps
from pandasql import sqldf

sns.set(font_scale=3)
sns.set(color_codes=True)
# %matplotlib inline
import matplotlib.pyplot as plt


plt.rcParams["figure.figsize"] = [16, 16] 


pysqldf = lambda q: sqldf(q, globals())

# %%
def replace_space_in_col_names(df):
    new_cols = [x.replace(" ","_") for x in df.columns]
    df.columns = new_cols

# %%
trans_df = pd.read_excel("../data/QuVa-GAIL DataRequest_4_5.xlsx","Daily Orders")
sf_opp_df = pd.read_excel("../data/QuVa-GAIL DataRequest_6_7_8_without_commas.xlsx","SF_OpportunityDetails")
sf_activities_df = pd.read_excel("../data/QuVa-GAIL DataRequest_6_7_8_without_commas.xlsx","SF_ActivityDetails")
sf_case_df = pd.read_excel("../data/QuVa-GAIL DataRequest_6_7_8_without_commas.xlsx","SF_Case")

replace_space_in_col_names(trans_df)
replace_space_in_col_names(sf_opp_df)
replace_space_in_col_names(sf_activities_df)
replace_space_in_col_names(sf_case_df)

trans_df["Customer_ID"] = trans_df["Customer_ID"].astype(str)
sf_opp_df["Customer_ID"] = sf_opp_df["Customer_ID"].astype(str)
sf_activities_df["Customer_ID"] = sf_activities_df["Customer_ID"].astype(str)
sf_case_df["Customer_id"] = sf_case_df["Customer_id"].astype(str)

# %%
trans_df.Order_Date = pd.to_datetime(trans_df.Order_Date).dt.to_period('D')
sf_opp_df["opp_date"] = sf_opp_df.Opportunity_Created_Date.dt.to_period('D')
sf_opp_df["Close_Date"] = sf_opp_df.Close_Date.dt.to_period('D')
sf_activities_df["activity_date"] = sf_activities_df.Activity_Last_Modified_Date.dt.to_period('D')
sf_case_df["case_date"] = sf_case_df.CreatedDate.dt.to_period('D')
sf_case_df.rename(columns={"Customer_id":"Customer_ID"},inplace=True)

# %%
trans_states_df = trans_df[["Customer_ID","Order_Date","Daily_Revenue"]]
trans_states_df = trans_states_df.groupby(["Customer_ID","Order_Date"]).sum().reset_index()
sf_activity_state_df = sf_activities_df[["Customer_ID","activity_date","Activity_Type"]]
sf_case_state_df = sf_case_df[["Customer_ID","case_date","Type","Reason"]]

# %%
#d = pd.merge(trans_states_df,sf_activity_state_df, on='Customer_ID',how='outer')
#d[d["activity_date"].notnull()  d["Daily_Revenue"].notnull()]
trans_states_df.columns = ["Customer_ID","activity_date","Activity_Type"]
d = trans_states_df.append(sf_activity_state_df)
d.sort_values(by=["Customer_ID","activity_date"],inplace=True)
#d[d.Customer_ID == '10002'].to_clipboard(index=False)
#d.to_clipboard(index=False)
#d[d.Customer_ID == '10002']

# %%
#opportunity journey

#get the won and lost opportunities only (exclude the open ones)
win_lost_opps_df = sf_opp_df[sf_opp_df.Opportunity_Status.isin(["Closed","Closed Won"])]
win_lost_opps_df = win_lost_opps_df[["Close_Date","Customer_/_Prospect_Type","Opportunity_Status","SF_Account_ID","SF_Opportunity_ID"]]
win_lost_opps_df.columns =["Close_Date","Customer_Type","Opp_Status","SF_Account_ID","SF_Opp_ID"]

#get opportunity stages

opp_stages_df = pd.read_excel("../data/QuVa-GAIL DataRequest_6_7_8_Addition2.xlsx","OpportunityStage")
replace_space_in_col_names(opp_stages_df)
opp_stages_df["CreatedDate"] = pd.to_datetime(opp_stages_df.CreatedDate).dt.to_period('D')
opp_stages_df = opp_stages_df.sort_values(by=["OpportunityId","CreatedDate","SystemModstamp"])
#exclude open opportunities
opp_stages_df = opp_stages_df[opp_stages_df.OpportunityId.isin(win_lost_opps_df.SF_Opp_ID)]

#create a dictionary of opps: key is opp_id, value is a pair of close date and the annual amount
#print(opp_annual_amount_dic["0064100000RUwD4AAL"][1])
opp_close_date_annual_amount_dic = sf_opp_df[["SF_Opportunity_ID","Close_Date","Annual_Amount","Opportunity_Status"]].set_index('SF_Opportunity_ID').T.to_dict('list')

# %%
opp_stages_sub_df = opp_stages_df[["CreatedDate","StageName","OpportunityId"]].drop_duplicates()
opp_stages_sub_df[opp_stages_sub_df.OpportunityId == "0064100000C5kEvAAJ"]
#opp_close_date_annual_amount_dic["0064100000C5kEvAAJ"]

opp_stages_grouped = dict(list(opp_stages_sub_df.groupby("OpportunityId")))
#dict(list(gb))
opp_funnel_df = pd.DataFrame()
#print(opp_stages_grouped.get_group("0064100000C5kEvAAJ"))
for opp_id in opp_stages_grouped.keys():
    opp_df = opp_stages_grouped[opp_id]
    stages_set = set()
    for stage in opp_df.StageName:
        stages_set.add(stage)

    if (len(stages_set) < 2):
        continue
    opp_path_string = '/'.join(stages_set)    
    opp_amount = opp_close_date_annual_amount_dic[opp_id][1]
    opp_days_gap = opp_close_date_annual_amount_dic[opp_id][0] - opp_df.CreatedDate.min()
    opp_final_status = opp_close_date_annual_amount_dic[opp_id][2]
    opp_path_string = opp_path_string + ("/" + opp_final_status)
    if "New" not in opp_path_string.split("/")[0] and "Lost" not in opp_path_string.split("/")[0]:
        opp_path_string = "01_New/" + opp_path_string

    opp_summary = pd.DataFrame({"opp_id": opp_id,
                                "opp_path_string" : opp_path_string,
                                "opp_amount":opp_amount,
                                "opp_days_gap": opp_days_gap},index=[0])
    opp_funnel_df = opp_funnel_df.append(opp_summary)

# %%
nodifier_df = opp_funnel_df.groupby("opp_path_string").agg({"opp_amount":"sum","opp_id":"count","opp_days_gap":"mean"}).reset_index()
nodifier_df = nodifier_df[["opp_path_string", "opp_id","opp_amount","opp_days_gap"]]
nodifier_df["label"] = nodifier_df.apply(lambda x : "{}\n{}@{}\n{}days".format(x["opp_path_string"].split("/")[-1],x["opp_id"],x["opp_amount"],int(x["opp_days_gap"])),axis=1)
nodifier_df.columns=["pathString","count","revenue","daysToAct","label"]
nodifier_df["label"] = nodifier_df["label"].str.replace(" ","_")
nodifier_df["label"] = nodifier_df["label"].str.replace("-","_")

nodifier_df["pathString"] = nodifier_df["pathString"].str.replace(" ","_")
nodifier_df["pathString"] = nodifier_df["pathString"].str.replace("-","_")


nodifier_df.to_csv("Qu_nodifierv1.csv",index=False)
nodifier_df
#list(nodifier_df["opp_path_string"])
# Out:
#                                             pathString  count     revenue  \
# 0    01_New/20_Needs_Assessment/40_Negotiation/60_F...      1    17445.00
# 1    01_New/20_Needs_Assessment/60_Fourth_Cycle_Com...      1    37200.00
# 2     01_New/20_Needs_Assessment/90_Lost/01_New/Closed      4  5962224.00
# 3    01_New/20_Needs_Assessment/90_Lost/10_Qualific...      4   141864.00
# 4    01_New/20_Needs_Assessment/90_Lost/10_Qualific...      3    13200.00
# 5    01_New/20_Needs_Assessment/90_Lost/25_Crosswal...      1    21762.00
# 6    01_New/20_Needs_Assessment/90_Lost/25_Crosswal...      2   387613.20
# 7    01_New/20_Needs_Assessment/90_Lost/55_Onboardi...      1        0.00
# 8    01_New/30_Received_Presentation/50_Contract_Si...      1  3139089.00
# 9    01_New/30_Received_Presentation/60_Fourth_Cycl...      1     5832.00
# 10   01_New/30_Received_Presentation/60_Fourth_Cycl...      1     9978.00
# 11   01_New/30_Received_Presentation/60_Fourth_Cycl...      1     6963.84
# 12   01_New/30_Received_Presentation/60_Fourth_Cycl...      1     2871.00
# 13   01_New/30_Received_Presentation/60_Fourth_Cycl...      1   221461.68
# 14   01_New/30_Received_Presentation/60_Fourth_Cycl...      1    12294.24
# 15   01_New/30_Received_Presentation/60_Fourth_Cycl...      1   292532.64
# 16   01_New/30_Received_Presentation/60_Fourth_Cycl...      2    42473.40
# 17   01_New/30_Received_Presentation/60_Fourth_Cycl...      2    38972.28
# 18   01_New/30_Received_Presentation/60_Fourth_Cycl...      3   101871.00
# 19   01_New/30_Received_Presentation/60_Fourth_Cycl...      1   132631.20
# 20   01_New/30_Received_Presentation/60_Fourth_Cycl...     17  2252176.20
# 21   01_New/30_Received_Presentation/60_Fourth_Cycl...      2    92848.80
# 22   01_New/30_Received_Presentation/60_Fourth_Cycl...      4  1263170.52
# 23   01_New/30_Received_Presentation/60_Fourth_Cycl...      1    55094.40
# 24   01_New/30_Received_Presentation/60_Fourth_Cycl...      1   656637.24
# 25   01_New/30_Received_Presentation/60_Fourth_Cycl...      2    34056.00
# 26   01_New/30_Received_Presentation/60_Fourth_Cycl...      2    21990.00
# 27   01_New/30_Received_Presentation/60_Fourth_Cycl...      1     1327.68
# 28   01_New/30_Received_Presentation/60_Fourth_Cycl...      1    44266.92
# 29   01_New/30_Received_Presentation/60_Fourth_Cycl...      2   665051.16
# ..                                                 ...    ...         ...
# 158  90_Lost/40_Negotiation/20_Needs_Assessment/30_...      1   844518.60
# 159  90_Lost/40_Negotiation/20_Needs_Assessment/Closed      1   104544.00
# 160  90_Lost/40_Negotiation/25_Crosswalk/Pricing/30...     32  3624748.92
# 161  90_Lost/40_Negotiation/25_Crosswalk/Pricing/Cl...      4   857436.00
# 162  90_Lost/40_Negotiation/30_Received_Presentatio...      3   503300.40
# 163  90_Lost/40_Negotiation/35_Presenting/01_New/Cl...      1        0.00
# 164  90_Lost/40_Negotiation/35_Presenting/10_Qualif...      1   366739.20
# 165  90_Lost/40_Negotiation/35_Presenting/20_Needs_...      1   382368.00
# 166  90_Lost/40_Negotiation/35_Presenting/20_Needs_...      1    12212.52
# 167  90_Lost/40_Negotiation/35_Presenting/25_Crossw...      1   115903.68
# 168        90_Lost/40_Negotiation/35_Presenting/Closed      3   206838.00
# 169  90_Lost/40_Negotiation/55_Onboarding/25_Crossw...      1     9600.00
# 170  90_Lost/40_Negotiation/55_Onboarding/35_Presen...      2     1200.00
# 171                      90_Lost/40_Negotiation/Closed      2     2767.32
# 172  90_Lost/40_Negotiation/Site_Visit/40_Negotiati...      1  1658190.00
# 173  90_Lost/40_Negotiation/Site_Visit/40_Negotiati...      1        0.00
# 174  90_Lost/50_Contract_Signed/40_Negotiation/30_R...      1    30408.00
# 175  90_Lost/50_Contract_Signed/40_Negotiation/Site...      1     2700.00
# 176  90_Lost/50_Contract_Signed/40_Negotiation/Site...      1        0.00
# 177  90_Lost/55_Onboarding/01_New/30_Received_Prese...      1       99.24
# 178                90_Lost/55_Onboarding/01_New/Closed      3   182280.00
# 179      90_Lost/55_Onboarding/10_Qualification/Closed      2    53868.00
# 180   90_Lost/55_Onboarding/20_Needs_Assessment/Closed      2   189600.00
# 181  90_Lost/55_Onboarding/25_Crosswalk/Pricing/01_...      1     2880.00
# 182  90_Lost/55_Onboarding/25_Crosswalk/Pricing/30_...      4   405662.40
# 183  90_Lost/55_Onboarding/25_Crosswalk/Pricing/Closed      2     2414.40
# 184         90_Lost/55_Onboarding/35_Presenting/Closed      2    18600.00
# 185  90_Lost/55_Onboarding/40_Negotiation/01_New/Cl...      1  1876305.96
# 186  90_Lost/55_Onboarding/40_Negotiation/25_Crossw...      2    16996.80
# 187                       90_Lost/55_Onboarding/Closed      8   121383.84
#
#       daysToAct                                    label
# 0     93.000000            Closed_Won\n1@17445.0\n93days
# 1     49.000000            Closed_Won\n1@37200.0\n49days
# 2     91.250000              Closed\n4@5962224.0\n91days
# 3    111.250000              Closed\n4@141864.0\n111days
# 4    109.333333               Closed\n3@13200.0\n109days
# 5    120.000000               Closed\n1@21762.0\n120days
# 6     29.500000               Closed\n2@387613.2\n29days
# 7     36.000000                    Closed\n1@0.0\n36days
# 8    173.000000             Closed\n1@3139089.0\n173days
# 9     33.000000             Closed_Won\n1@5832.0\n33days
# 10    42.000000             Closed_Won\n1@9978.0\n42days
# 11    33.000000            Closed_Won\n1@6963.84\n33days
# 12    38.000000             Closed_Won\n1@2871.0\n38days
# 13   143.000000         Closed_Won\n1@221461.68\n143days
# 14    57.000000           Closed_Won\n1@12294.24\n57days
# 15   184.000000         Closed_Won\n1@292532.64\n184days
# 16   -81.500000           Closed_Won\n2@42473.4\n_81days
# 17    75.500000           Closed_Won\n2@38972.28\n75days
# 18   153.000000          Closed_Won\n3@101871.0\n153days
# 19    24.000000           Closed_Won\n1@132631.2\n24days
# 20    73.176471         Closed_Won\n17@2252176.2\n73days
# 21    77.000000            Closed_Won\n2@92848.8\n77days
# 22   -20.000000        Closed_Won\n4@1263170.52\n_20days
# 23    86.000000            Closed_Won\n1@55094.4\n86days
# 24   168.000000         Closed_Won\n1@656637.24\n168days
# 25    23.000000            Closed_Won\n2@34056.0\n23days
# 26    70.000000            Closed_Won\n2@21990.0\n70days
# 27     7.000000             Closed_Won\n1@1327.68\n7days
# 28   108.000000          Closed_Won\n1@44266.92\n108days
# 29    44.500000  Closed_Won\n2@665051.1599999999\n44days
# ..          ...                                      ...
# 158  219.000000              Closed\n1@844518.6\n219days
# 159   91.000000               Closed\n1@104544.0\n91days
# 160   97.812500    Closed\n32@3624748.9200000004\n97days
# 161  136.500000              Closed\n4@857436.0\n136days
# 162  165.333333              Closed\n3@503300.4\n165days
# 163  102.000000                   Closed\n1@0.0\n102days
# 164  154.000000              Closed\n1@366739.2\n154days
# 165  124.000000              Closed\n1@382368.0\n124days
# 166  178.000000              Closed\n1@12212.52\n178days
# 167   69.000000              Closed\n1@115903.68\n69days
# 168  105.666667              Closed\n3@206838.0\n105days
# 169   41.000000                 Closed\n1@9600.0\n41days
# 170  120.500000                Closed\n2@1200.0\n120days
# 171  103.500000    Closed\n2@2767.3199999999997\n103days
# 172  189.000000             Closed\n1@1658190.0\n189days
# 173   37.000000                    Closed\n1@0.0\n37days
# 174   30.000000                Closed\n1@30408.0\n30days
# 175  106.000000                Closed\n1@2700.0\n106days
# 176   78.000000                    Closed\n1@0.0\n78days
# 177  172.000000                 Closed\n1@99.24\n172days
# 178   54.333333               Closed\n3@182280.0\n54days
# 179   79.000000                Closed\n2@53868.0\n79days
# 180   61.000000               Closed\n2@189600.0\n61days
# 181   51.000000                 Closed\n1@2880.0\n51days
# 182   70.000000               Closed\n4@405662.4\n70days
# 183   16.000000                 Closed\n2@2414.4\n16days
# 184   33.500000                Closed\n2@18600.0\n33days
# 185   19.000000             Closed\n1@1876305.96\n19days
# 186  110.000000               Closed\n2@16996.8\n110days
# 187   61.875000              Closed\n8@121383.84\n61days
#
# [188 rows x 5 columns]
